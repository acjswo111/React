# %%
# Firebase

# %% [markdown]
# 사용해볼 데이터베이스는 Firebase에 제품툴에 있는 Firestore를 사용해보자

# %%
# Firebase 설정법

# %% [markdown]
# FireStore = firebase에서 제공하는 서비스중 하나로 확장 가능한 NoSQL클라우드 데이터베이스

# %% [markdown]
# 1. 프로젝트 생성
# 2. 왼쪽tap에 firestore database ㄱㄱ
# 3. test모드로 생성 (후에 프로덕션모드로 바꿀수있다.) => test모드로해야 local에서 데이터 요청가능
# 4. 위치설정 (위치설정은 한번설정하면 바꾸기 x)
# 5. 컬렉션 만들기

# %% [markdown]
# # Collection : document의 집합
# # Document : json형식의 데이터를 저장

# %%
# firebase 연동하기

# %% [markdown]
# 1: 리액트 프로젝트에 yarn add firebase 패키지 설치
#
# 2. src 폴더에 js파일 하나 생성 (firebase.js)

# %%
from IPython.display import Image
Image("img/import firebase.png")
# config의 내용은 firebase홈페이지에서 웹에서 앱등록을하면 
# config 스크립트를 가져온다.

# %% [markdown]
# 3. app.js에 import한다.
#
# import firestore from "./firebase";

# %%
# firebase 데이터 불러와보기

# %%
Image("img/firebase data.png")
# 데이터를 보면 딕셔너리 형태를 이루고 있다.

# %%
Image("img/firebase data가져오기.png")
# firebase 연동하여 데이터 가져오는방법과 forEach문을 이용하여 모든데이터가져오기

# %%
# firebase에 데이터 추가 수정 삭제방법

# %%
Image("img/firebase data info.png")
