# %%
# keyframes
from IPython.display import Image

# %% [markdown]
# keyframes 는 styled-components안에 들어있다.
#
# 웹에서 역동적인것을 구현할땐 transition과 animation 속성을 많이 쓴다.
#
# transition -> 단순한 효과를 줄 때
# animation -> 다이나믹 효과를 줄 때
#
# keyframes은 animation에서 사용하는 속성 중 하나.

# %%
# keyframes 사용법

# %% [markdown]
# import styled, {keyframes} from "styled-components";
#
# keyframes는 styled-components안에있다.

# %%
Image("img/keyframes.png")
